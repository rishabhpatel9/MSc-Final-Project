# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore
# Out:
# 2023-08-04 23:41:46.505624: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-04 23:41:47.069234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#limit VRAM usage
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2023-08-04 23:41:47.559754: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:41:47.576133: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:41:47.576295: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# Load the dataset and create a dataframe with image paths and labels
dataset_path = "datasets/dataset1/data/"
images = []
labels = []
for folder in os.listdir(dataset_path):
    if os.path.isdir(os.path.join(dataset_path, folder)):
        for file in os.listdir(os.path.join(dataset_path, folder)):
            if file.endswith(".jpg"):
                images.append(os.path.join(dataset_path, folder, file))
                labels.append(folder)
df = pd.DataFrame({"image": images, "label": labels})

# %%
# Load the validation set and create a dataframe with image paths and labels
validation_path = "datasets/dataset1/validation/"
images = []
labels = []
for folder in os.listdir(dataset_path):
    if os.path.isdir(os.path.join(dataset_path, folder)):
        for file in os.listdir(os.path.join(dataset_path, folder)):
            if file.endswith(".jpg"):
                images.append(os.path.join(dataset_path, folder, file))
                labels.append(folder)
vf = pd.DataFrame({"image": images, "label": labels})

# %%
# Define a function to preprocess the images: resize, grayscale, histogram equalization
def preprocess_image(image_path):
  image = cv2.imread(image_path)
  image = cv2.resize(image, (64, 64))
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.equalizeHist(image)
  image = image / 255.0
  image = np.expand_dims(image, axis=2)
  return image

# %%
# Apply the preprocessing function to the images and convert the labels to numeric values
X_train = np.array([preprocess_image(image) for image in df["image"]])
y_train = np.array([0 if label == "male" else 1 for label in df["label"]])

X_test = np.array([preprocess_image(image) for image in vf["image"]])
y_test = np.array([0 if label == "male" else 1 for label in df["label"]])

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(64, 64, 1)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(256, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,272,833
# Trainable params: 1,272,833
# Non-trainable params: 0
# _________________________________________________________________
# 2023-08-04 23:42:15.704042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:42:15.704277: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:42:15.704439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:42:15.995733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:42:15.995895: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:42:15.996017: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-04 23:42:15.996107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6024 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:07:00.0, compute capability: 8.6

# %%
# Compile and fit the model on the reweighted train set
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
early_stopping = EarlyStopping(monitor="val_loss", patience=5)
history = model.fit(X_train, y_train, batch_size=32, epochs=50,
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2023-08-04 23:42:17.900057: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-08-04 23:42:18.421908: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-04 23:42:18.424428: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f60473c8c10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-04 23:42:18.424441: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3080, Compute Capability 8.6
# 2023-08-04 23:42:18.427418: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-04 23:42:18.535026: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1470/1470 [==============================] - 9s 4ms/step - loss: 0.2526 - accuracy: 0.8923 - val_loss: 0.1500 - val_accuracy: 0.9450
# Epoch 2/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.1573 - accuracy: 0.9434 - val_loss: 0.1271 - val_accuracy: 0.9530
# Epoch 3/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.1356 - accuracy: 0.9528 - val_loss: 0.1097 - val_accuracy: 0.9619
# Epoch 4/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.1205 - accuracy: 0.9580 - val_loss: 0.0992 - val_accuracy: 0.9647
# Epoch 5/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.1126 - accuracy: 0.9599 - val_loss: 0.0811 - val_accuracy: 0.9714
# Epoch 6/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0968 - accuracy: 0.9656 - val_loss: 0.0770 - val_accuracy: 0.9729
# Epoch 7/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0893 - accuracy: 0.9682 - val_loss: 0.0706 - val_accuracy: 0.9747
# Epoch 8/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0779 - accuracy: 0.9722 - val_loss: 0.0539 - val_accuracy: 0.9808
# Epoch 9/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0694 - accuracy: 0.9741 - val_loss: 0.0460 - val_accuracy: 0.9832
# Epoch 10/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0617 - accuracy: 0.9769 - val_loss: 0.0429 - val_accuracy: 0.9841
# Epoch 11/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0548 - accuracy: 0.9794 - val_loss: 0.0343 - val_accuracy: 0.9871
# Epoch 12/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0475 - accuracy: 0.9822 - val_loss: 0.0290 - val_accuracy: 0.9891
# Epoch 13/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0439 - accuracy: 0.9845 - val_loss: 0.0263 - val_accuracy: 0.9912
# Epoch 14/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0393 - accuracy: 0.9852 - val_loss: 0.0216 - val_accuracy: 0.9928
# Epoch 15/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0343 - accuracy: 0.9866 - val_loss: 0.0212 - val_accuracy: 0.9922
# Epoch 16/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0315 - accuracy: 0.9877 - val_loss: 0.0179 - val_accuracy: 0.9931
# Epoch 17/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0303 - accuracy: 0.9884 - val_loss: 0.0165 - val_accuracy: 0.9940
# Epoch 18/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0271 - accuracy: 0.9895 - val_loss: 0.0126 - val_accuracy: 0.9959
# Epoch 19/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0252 - accuracy: 0.9901 - val_loss: 0.0091 - val_accuracy: 0.9970
# Epoch 20/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.0082 - val_accuracy: 0.9974
# Epoch 21/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0244 - accuracy: 0.9908 - val_loss: 0.0097 - val_accuracy: 0.9974
# Epoch 22/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0240 - accuracy: 0.9915 - val_loss: 0.0124 - val_accuracy: 0.9953
# Epoch 23/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0227 - accuracy: 0.9916 - val_loss: 0.0174 - val_accuracy: 0.9942
# Epoch 24/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0217 - accuracy: 0.9919 - val_loss: 0.0083 - val_accuracy: 0.9971
# Epoch 25/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0231 - accuracy: 0.9921 - val_loss: 0.0079 - val_accuracy: 0.9978
# Epoch 26/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.0122 - val_accuracy: 0.9955
# Epoch 27/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0085 - val_accuracy: 0.9974
# Epoch 28/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.0066 - val_accuracy: 0.9983
# Epoch 29/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0187 - accuracy: 0.9931 - val_loss: 0.0064 - val_accuracy: 0.9983
# Epoch 30/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.0053 - val_accuracy: 0.9984
# Epoch 31/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0182 - accuracy: 0.9934 - val_loss: 0.0047 - val_accuracy: 0.9988
# Epoch 32/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0167 - accuracy: 0.9943 - val_loss: 0.0075 - val_accuracy: 0.9972
# Epoch 33/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0028 - val_accuracy: 0.9992
# Epoch 34/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.0059 - val_accuracy: 0.9985
# Epoch 35/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.0119 - val_accuracy: 0.9962
# Epoch 36/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0052 - val_accuracy: 0.9983
# Epoch 37/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0021 - val_accuracy: 0.9994
# Epoch 38/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.0045 - val_accuracy: 0.9986
# Epoch 39/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.0036 - val_accuracy: 0.9991
# Epoch 40/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.0113 - val_accuracy: 0.9962
# Epoch 41/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0066 - val_accuracy: 0.9982
# Epoch 42/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.0019 - val_accuracy: 0.9997
# Epoch 43/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.0041 - val_accuracy: 0.9989
# Epoch 44/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0133 - accuracy: 0.9952 - val_loss: 0.0030 - val_accuracy: 0.9992
# Epoch 45/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0209 - val_accuracy: 0.9932
# Epoch 46/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0124 - val_accuracy: 0.9959
# Epoch 47/50
# 1470/1470 [==============================] - 5s 3ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.0033 - val_accuracy: 0.9989

# %%
# Plot the training and validation accuracy and loss curves
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(history.history["accuracy"], label="train accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
y_pred = model.predict(X_test).round().ravel()
test_acc = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
test_cm = confusion_matrix(y_test, y_pred)
print("Test accuracy:", test_acc)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test confusion matrix:")
print(test_cm)
# Out:
# 1470/1470 [==============================] - 1s 741us/step
# Test accuracy: 0.9989363738858517
# Test Precision: 0.9985811943763704
# Test Recall: 0.9992685969969454
# Test confusion matrix:
# [[23733    33]
#  [   17 23226]]
